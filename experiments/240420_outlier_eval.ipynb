# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df_labels = pd.read_csv("../strength_covariance/data_ays/label_dict.csv")
label_dict = df_labels.to_dict(orient="records")[0]

# %%
df = pd.read_csv("../data/models_w_props.csv",index_col = 0)
print(df.columns)
# Out:
# Index(['llnl_ported_kimcode', 'strength_MPa', 'disqualified', 'SF_jamming',
#        'bcc_fraction', 'hcp_fraction', 'type', 'llnl_code', 'model', 'type1',
#        'type2', 'kim_code', 'study_details', 'lattice_constant_bcc',
#        'lattice_constant_diamond', 'lattice_constant_fcc',
#        'lattice_constant_sc', 'bulk_modulus_bcc', 'bulk_modulus_diamond',
#        'bulk_modulus_fcc', 'bulk_modulus_sc', 'c44_bcc', 'c44_diamond',
#        'c44_fcc', 'c44_sc', 'c12_bcc', 'c12_diamond', 'c12_fcc', 'c12_sc',
#        'c11_bcc', 'c11_diamond', 'c11_fcc', 'c11_sc', 'cohesive_energy_bcc',
#        'cohesive_energy_diamond', 'cohesive_energy_fcc', 'cohesive_energy_sc',
#        'thermal_expansion_coeff_bcc', 'thermal_expansion_coeff_diamond',
#        'thermal_expansion_coeff_fcc', 'surface_energy_100_bcc',
#        'surface_energy_100_fcc', 'surface_energy_110_bcc',
#        'surface_energy_110_fcc', 'surface_energy_111_bcc',
#        'surface_energy_111_fcc', 'surface_energy_121_bcc',
#        'surface_energy_121_fcc', 'ideal_surface_energy_100_bcc',
#        'ideal_surface_energy_100_fcc', 'ideal_surface_energy_110_bcc',
#        'ideal_surface_energy_110_fcc', 'ideal_surface_energy_111_bcc',
#        'ideal_surface_energy_111_fcc', 'ideal_surface_energy_121_bcc',
#        'ideal_surface_energy_121_fcc', 'extr_stack_fault_energy_fcc',
#        'intr_stack_fault_energy_fcc', 'unstable_stack_energy_fcc',
#        'unstable_stack_energy_slip_fraction_fcc',
#        'unstable_twinning_energy_fcc',
#        'unstable_twinning_energy_slip_fraction_fcc',
#        'relaxed_formation_potential_energy_bcc',
#        'relaxed_formation_potential_energy_diamond',
#        'relaxed_formation_potential_energy_fcc',
#        'relaxed_formation_potential_energy_hcp',
#        'unrelaxed_formation_potential_energy_bcc',
#        'unrelaxed_formation_potential_energy_diamond',
#        'unrelaxed_formation_potential_energy_fcc',
#        'unrelaxed_formation_potential_energy_hcp',
#        'vacancy_migration_energy_bcc', 'vacancy_migration_energy_diamond',
#        'vacancy_migration_energy_fcc', 'vacancy_migration_energy_hcp',
#        'vacancy_migration_energy_sc', 'relaxation_volume_bcc',
#        'relaxation_volume_diamond', 'relaxation_volume_fcc',
#        'relaxation_volume_hcp', 'units', 'testnames'],
#       dtype='object')

# %%
df = df[['c44_fcc','c44_bcc','c44_sc',
         'c11_fcc','c11_bcc','c11_sc',
         'c12_fcc','c12_bcc','c12_sc',
         'bulk_modulus_fcc','bulk_modulus_bcc','bulk_modulus_sc',
         'vacancy_migration_energy_fcc','vacancy_migration_energy_bcc','vacancy_migration_energy_sc',
         'extr_stack_fault_energy_fcc','intr_stack_fault_energy_fcc',
         'cohesive_energy_fcc','cohesive_energy_bcc','cohesive_energy_diamond']
         ]
df.columns = [label_dict[i] for i in df.columns]
df.columns
# Out:
# Index(['C44 FCC', 'C44 BCC', 'C44 SC', 'C11 FCC', 'C11 BCC', 'C11 SC',
#        'C12 FCC', 'C12 BCC', 'C12 SC', 'Bulk Modulus FCC', 'Bulk Modulus BCC',
#        'Bulk Modulus SC', 'VME FCC', 'VME BCC', 'VME SC', 'eSFE FCC',
#        'iSFE FCC', 'Coh. Energy FCC', 'Coh. Energy BCC',
#        'Coh. Energy Diamond'],
#       dtype='object')

# %%
ax = df.boxplot(['eSFE FCC',
                 'iSFE FCC'],
           figsize = (3,3),
           rot = 90)
ax.set_ylabel(r'ev/A$^2$')
plt.savefig("../figures/si/bp_sfe.pdf",bbox_inches = 'tight')
plt.show()

# %%
ax = df.boxplot(['Coh. Energy FCC',
                 'Coh. Energy BCC',
                 'Coh. Energy Diamond'],
           figsize = (3,3),
           rot = 90)
ax.set_ylabel(r'ev/A$^2$')
plt.savefig("../figures/si/bp_cohEn.pdf",bbox_inches = 'tight')
plt.show()

# %%
ax = df.boxplot(['C44 FCC','C44 BCC','C44 SC',
                 'C11 FCC','C11 BCC','C11 SC',
                 'C12 FCC','C12 BCC','C12 SC',
                 'Bulk Modulus FCC', 'Bulk Modulus BCC', 'Bulk Modulus SC'],
                 rot=90,
                 figsize = (5,3))
ax.set_ylabel('GPa')
plt.savefig("../figures/si/bp_ec.pdf",bbox_inches = 'tight')
plt.show()
